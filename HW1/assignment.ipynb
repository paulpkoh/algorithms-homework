# %% [markdown]
# # Homework 1
#
# ## Instructions
# Complete the tasks below.

# %% [markdown]
# ## Problem 1: Setup
#
# Write code to demonstrate your Python environment is set up correctly.

# %%
import sys
print(f"Python version: {sys.version}")
print("Environment setup successful!")

# %% [markdown]
# ## Problem 2: Your Work Here
#
# Replace this with your actual homework assignment.

# %%
# Add your code here
